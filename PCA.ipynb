# %%
import pandas as pd
import numpy as np
import sklearn 
from sklearn.decomposition import PCA, KernelPCA

# %%
PCA_test = pd.read_csv('/home/guatam-admin/Vijay_BCI/Data-Mason-1/EEG_average/Mason-avg-u.csv')
PCA_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30296 entries, 0 to 30295
# Data columns (total 31 columns):
# Fp1     30296 non-null float64
# Fz      30296 non-null float64
# F3      30296 non-null float64
# F7      30296 non-null float64
# FT9     30296 non-null float64
# FC5     30296 non-null float64
# FC1     30296 non-null float64
# C3      30296 non-null float64
# T7      30296 non-null float64
# TP9     30296 non-null float64
# CP5     30296 non-null float64
# CP1     30296 non-null float64
# Pz      30296 non-null float64
# P3      30296 non-null float64
# P7      30296 non-null float64
# O1      30296 non-null float64
# Oz      30296 non-null float64
# O2      30296 non-null float64
# P4      30296 non-null float64
# P8      30296 non-null float64
# TP10    30296 non-null float64
# CP6     30296 non-null float64
# CP2     30296 non-null float64
# C4      30296 non-null float64
# T8      30296 non-null float64
# FT10    30296 non-null float64
# ...

# %%
scikit_kpca = KernelPCA(n_components=13, kernel='linear')
PCA_final = scikit_kpca.fit_transform(PCA_test)

# %%
PCA_final_cp = pd.DataFrame(PCA_final)

# %%
PCA_final_cp.head(5)
# Out:
#           0          1           2          3          4          5   \
# 0   3.905489  -6.889913    0.487464  -1.908823   7.986749 -20.070163
# 1  -1.494347 -27.978861 -105.273232  -6.651669 -26.558044  -1.349752
# 2   1.353509 -12.123517  -13.016759  -5.301046  18.236454  38.897525
# 3 -10.230335 -36.979839  -96.319959   5.383854  -6.456793  12.935722
# 4  10.265315  15.135619   28.856645 -11.730543  22.679485  -1.352728
#
#           6          7          8          9          10        11         12
# 0  -9.686644  -1.831211  11.989010  19.884063   0.223245 -2.555474   9.041796
# 1  -2.917568   6.166019  22.148146  -1.847724 -14.662195 -3.374947   7.382437
# 2 -39.183270  -0.523710   0.658825  -0.267297  -3.949600  1.659770  14.638604
# 3  11.873847  -1.594239  13.629666  -7.140683 -14.093165 -8.710373   9.056124
# 4   7.909689  10.312858  23.841460   5.342981 -22.250494  8.171608  13.770310

# %%
PCA_test.head(5)
# Out:
#         Fp1        Fz         F3         F7       FT9        FC5       FC1  \
# 0 -6.214393  2.482471  22.753094   3.054672  2.447698  -5.317648 -4.504718
# 1 -2.792368  0.539594  -0.724479   4.122693  2.798696 -19.882481 -4.416183
# 2 -2.911586  0.642375  10.529490   6.357292 -4.687177   2.926546 -4.549714
# 3  9.490343  4.549658  -8.211786  10.709134 -0.850806  -6.554759  0.532891
# 4 -8.317406 -2.732164  -5.991141  -4.096896 -5.732177 -10.938132 -5.364667
#
#           C3         T7        TP9    ...           CP6       CP2        C4  \
# 0  -2.580297  17.741341   4.143145    ...     15.239147  1.155543  6.814796
# 1  -9.699627   3.982388   7.929920    ...      7.861553  0.297285  5.045652
# 2   2.852641 -32.333044  -2.484899    ...      4.737690 -4.209927 -2.230322
# 3 -10.633273   4.275645   4.361280    ...      2.362503 -2.619287 -0.494608
# 4  -3.799365  18.478091 -12.029318    ...     10.274750 -1.703868 -2.689542
#
# ...

# %%
scikit_kpca.lamdas_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b19f7f6bd029> in <module>()
# ----> 1 scikit_kpca.lamdas_
#
# AttributeError: 'KernelPCA' object has no attribute 'lamdas_'
